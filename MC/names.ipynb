# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.20/04

# %%
# read in data
inFile1 = ROOT . TFile . Open ( "ttH_mc16a_mc16d_me16e_merge.root" , " READ " )
tree1 = inFile1 . Get ( "ttHyyTree" )

inFile2 = ROOT . TFile . Open ( "ttgammgamma_mc16a_mc16d_mc16e_merge.root" , " READ " )
tree2 = inFile2 . Get ( "ttHyyTree" )
# Out:
# ReadStreamerInfo, class:string, illegal uid=-2

# %%
# ttH
for i in tree1.GetListOfBranches():
  print i.GetName()
# Out:
# hgamtool_cat
# applyNoDalitz
# applyTightPhotonID
# applyPhotonIsolation
# applyMassWindowCut
# is_passed_id
# is_passed_isolation
# is_passed_massWindow
# is_passed_Zey
# is_passed_presel
# is_passed_ttHhad_4jet1bjet
# is_passed_ttHhad_4jet2bjet
# is_passed_ttHhad_5jet1bjet
# is_passed_ttHhad_5jet2bjet
# is_passed_ttHhad_6jet1bjet
# is_passed_ttHhad_6jet2bjet
# is_passed_ttHhad
# is_passed_tHlep_0fwd
# is_passed_tHlep_1fwd
# is_passed_ttHlep
# is_passed_ttHhad_bdt1
# is_passed_ttHhad_bdt2
# is_passed_ttHhad_bdt3
# is_passed_ttHhad_bdt4
# is_passed_tHhad_bdt
# is_passed_tHlep_bdt1
# is_passed_tHlep_bdt2
# is_passed_ttHlep_bdt1
# is_passed_ttHlep_bdt2
# is_passed_ttHhad_bdt_presel
# is_passed_ttHlep_bdt_presel
# y1_pt
# y1_px
# y1_py
# y1_pz
# y1_E
# y1_eta
# y1_phi
# y2_pt
# y2_px
# y2_py
# y2_pz
# y2_E
# y2_eta
# y2_phi
# m_yy
# cosTS_yy
# Dphi_y_y
# DR_y_y
# y1_is_tight
# y2_is_tight
# y1_is_loose
# y2_is_loose
# y1_is_loosep2
# y1_is_loosep3
# y1_is_loosep4
# y1_is_loosep5
# y2_is_loosep2
# y2_is_loosep3
# y2_is_loosep4
# y2_is_loosep5
# y1_is_isolated
# y2_is_isolated
# y1_ptcone20
# y2_ptcone20
# y1_topoetcone20
# y2_topoetcone20
# y1_topoetcone40
# y2_topoetcone40
# y1_isConv
# y2_isConv
# n_jets25
# n_jets30
# n_jets35
# n_jets25_fwd
# n_jets30_fwd
# n_jets35_fwd
# n_jets25_central
# n_jets30_central
# n_jets35_central
# n_bjets25_60
# n_bjets30_60
# n_bjets35_60
# n_bjets25_70
# n_bjets30_70
# n_bjets35_70
# n_bjets25_77
# n_bjets30_77
# n_bjets35_77
# n_bjets25_85
# n_bjets30_85
# n_bjets35_85
# jet_pt
# jet_eta
# jet_phi
# jet_E
# jet_m
# jet_MV2c10
# jet_PCbtag
# jet_btag60
# jet_btag70
# jet_btag77
# jet_btag85
# n_lep
# n_el
# n_mu
# n_mu15
# mu_pt
# mu_eta
# mu_phi
# el_pt
# el_eta
# el_phi
# lep_pt
# lep_eta
# lep_phi
# m_ll
# DR_ll
# pt_ll
# met
# met_x
# met_y
# met_z
# sumet
# metsig
# TST_met
# TST_sumet
# pt_jj
# pt_yyj
# m_jj
# Deta_j_j
# DRmin_y_j
# DRmin_y_j_2
# m_alljet_30
# pTlepMET
# HT_30
# HT_all
# HT_event
# mass_multijet
# massT
# mT
# mT_top
# mu
# top_mass
# runNumber
# eventNumber
# weight
# weight_xsec_br_filter
# lumiXsecWeight
# weight_vertex
# weight_total
# cut_category_weight
# bdt_category_weight
# hgamtool_cat_w
# hgamtool_bdt_w

# %%
# ttyy
for j in tree2.GetListOfBranches():
  print j.GetName()
# Out:
# hgamtool_cat
# applyNoDalitz
# applyTightPhotonID
# applyPhotonIsolation
# applyMassWindowCut
# is_passed_id
# is_passed_isolation
# is_passed_massWindow
# is_passed_Zey
# is_passed_presel
# is_passed_ttHhad_4jet1bjet
# is_passed_ttHhad_4jet2bjet
# is_passed_ttHhad_5jet1bjet
# is_passed_ttHhad_5jet2bjet
# is_passed_ttHhad_6jet1bjet
# is_passed_ttHhad_6jet2bjet
# is_passed_ttHhad
# is_passed_tHlep_0fwd
# is_passed_tHlep_1fwd
# is_passed_ttHlep
# is_passed_ttHhad_bdt1
# is_passed_ttHhad_bdt2
# is_passed_ttHhad_bdt3
# is_passed_ttHhad_bdt4
# is_passed_tHhad_bdt
# is_passed_tHlep_bdt1
# is_passed_tHlep_bdt2
# is_passed_ttHlep_bdt1
# is_passed_ttHlep_bdt2
# is_passed_ttHhad_bdt_presel
# is_passed_ttHlep_bdt_presel
# y1_pt
# y1_px
# y1_py
# y1_pz
# y1_E
# y1_eta
# y1_phi
# y2_pt
# y2_px
# y2_py
# y2_pz
# y2_E
# y2_eta
# y2_phi
# m_yy
# cosTS_yy
# Dphi_y_y
# DR_y_y
# y1_is_tight
# y2_is_tight
# y1_is_loose
# y2_is_loose
# y1_is_loosep2
# y1_is_loosep3
# y1_is_loosep4
# y1_is_loosep5
# y2_is_loosep2
# y2_is_loosep3
# y2_is_loosep4
# y2_is_loosep5
# y1_is_isolated
# y2_is_isolated
# y1_ptcone20
# y2_ptcone20
# y1_topoetcone20
# y2_topoetcone20
# y1_topoetcone40
# y2_topoetcone40
# y1_isConv
# y2_isConv
# n_jets25
# n_jets30
# n_jets35
# n_jets25_fwd
# n_jets30_fwd
# n_jets35_fwd
# n_jets25_central
# n_jets30_central
# n_jets35_central
# n_bjets25_60
# n_bjets30_60
# n_bjets35_60
# n_bjets25_70
# n_bjets30_70
# n_bjets35_70
# n_bjets25_77
# n_bjets30_77
# n_bjets35_77
# n_bjets25_85
# n_bjets30_85
# n_bjets35_85
# jet_pt
# jet_eta
# jet_phi
# jet_E
# jet_m
# jet_MV2c10
# jet_PCbtag
# jet_btag60
# jet_btag70
# jet_btag77
# jet_btag85
# n_lep
# n_el
# n_mu
# n_mu15
# mu_pt
# mu_eta
# mu_phi
# el_pt
# el_eta
# el_phi
# lep_pt
# lep_eta
# lep_phi
# m_ll
# DR_ll
# pt_ll
# met
# met_x
# met_y
# met_z
# sumet
# metsig
# TST_met
# TST_sumet
# pt_jj
# pt_yyj
# m_jj
# Deta_j_j
# DRmin_y_j
# DRmin_y_j_2
# m_alljet_30
# pTlepMET
# HT_30
# HT_all
# HT_event
# mass_multijet
# massT
# mT
# mT_top
# mu
# top_mass
# runNumber
# eventNumber
# weight
# weight_xsec_br_filter
# lumiXsecWeight
# weight_vertex
# weight_total
# cut_category_weight
# bdt_category_weight
# hgamtool_cat_w
# hgamtool_bdt_w
